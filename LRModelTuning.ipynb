# %%
import findspark

# %%
findspark.init('/home/huy/spark-2.2.3-bin-hadoop2.7')

# %%
from pyspark.sql import SparkSession
from pyspark import SparkContext

# définir un SparkContext en local. Permet de travailler avec les RDD
sc = SparkContext.getOrCreate()

# Construire une session Spark
# SparkSession est une couche supérieure à SparkContext
spark = SparkSession.builder.appName('Spark Context').getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.2.15:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.2.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_raw = spark.read.csv("YearPredictionMSD.txt")

# toutes les colonnes sont du type string
df_raw.sample(False, .00001, seed = 222).toPandas()
# Out:
#     _c0       _c1        _c2        _c3       _c4        _c5        _c6  \
# 0  2007  49.83538    2.61013   17.00197  -9.50786  -23.94269  -14.72739
# 1  2009  45.78269   34.74613   -8.52873  11.44336  -18.00745  -29.79324
# 2  2007  43.61806  -12.13404  -21.41169   0.17262   23.94724    3.72902
# 3  2006  46.79964   54.54515   11.05619   2.00775   11.86970  -10.15977
# 4  2006  52.00132   35.66485   34.37876   1.69847  -34.09650  -19.76410
#
#         _c7       _c8       _c9  ...       _c81        _c82       _c83  \
# 0   4.47792   4.06217   4.78611  ...   10.59593    81.25012   33.10853
# 1  11.83189  -5.26578   0.34463  ...    8.23981  -120.67690  -56.06567
# 2  13.61887  -3.44822  -2.09872  ...   20.43382   -74.56965   59.65242
# 3   6.25193   5.34281   1.45345  ...    7.26790  -203.19105   84.51010
# 4  13.33325   5.54795   6.81785  ...  -17.10870  -121.60406  -31.96296
#
#         _c84      _c85       _c86        _c87      _c88       _c89       _c90
# 0   -7.46066   7.60570   91.36251   -66.34214   9.62220  119.81564    2.81304
# 1   17.67264   8.23461  -46.53563    39.40150   9.44279  -24.93795   -8.67221
# 2  131.46903   6.07510   34.06221  -162.45943   2.73542   66.37659  -25.99604
# 3  -73.76258  35.57993   59.14017     3.72889  -8.86871   45.47880  -11.22200
# 4  -40.16986  -5.51689   15.41615   -78.71597   2.63836   -8.23705    0.84104
#
# [5 rows x 91 columns]

# %% [markdown]
# https://spark.apache.org/docs/latest/ml-tuning
#
# Tuning is using data to find the best model or parameters for a given task.
#
# Tuning may be done for
# - individual Estimators such as LogisticRegression,
# - or for entire Pipelines which include multiple algorithms, featurization, and other steps.
#
# Users can tune an entire Pipeline at once, rather than tuning each element in the Pipeline separately.
#
# MLlib supports model selection using tools such as CrossValidator and TrainValidationSplit. These tools require the following items:
#
# - Estimator: algorithm or Pipeline to tune
# - Set of ParamMaps: parameters to choose from, sometimes called a “parameter grid” to search over
# - Evaluator: metric to measure how well a fitted Model does on held-out test data
#
# At a high level, these model selection tools work as follows:
#
# 1. They split the input data into separate training and test datasets.
# 2. For each (training, test) pair, they iterate through the set of ParamMaps:
# 3. For each ParamMap, they fit the Estimator using those parameters, get the fitted Model, and evaluate the Model’s performance using the Evaluator.
# 4. They select the Model produced by the best-performing set of parameters.
#
# 3
#
# The Evaluator can be
# a RegressionEvaluator for regression problems,
# a BinaryClassificationEvaluator for binary data,
# a MulticlassClassificationEvaluator for multiclass problems,
# a MultilabelClassificationEvaluator for multi-label classifications,
# or a RankingEvaluator for ranking problems.
#
# The default metric used to choose the best ParamMap can be overridden by the setMetricName method in each of these evaluators.
#
# To help construct the **parameter grid**, users can use the ParamGridBuilder utility.
#
# Le model tuning permet de régler les paramètres d'un modèle pour éviter le overfitting.
#
# Méthode la plus utilisée cross-validation
#
# 1 Choix du modèle à optimiser (model selection)
#
# 2 Création d'une grille de paramètres (parameter grid)
#
# 3 Choix d'une métrique d'évaluation (evaluator metric)
#
# 4 Mise en place d'un crossValidator

# %% [markdown]
# Objectif: régler les paramètres du modèle pour améliorer sa robustesse.
#
# Robutesse: être efficace face à une nouvelle base de données. Le contraire de overfitting.

# %% [markdown]
# ### Mettre le jeu de données en format svmlib

# %%
from pyspark.sql.functions import col

# pour ttes les colonnes de 1 à 13, cast en "double"
exprs = [col(c).cast("double") for c in df_raw.columns[1:13]]

# la première colonne est l'année et est en int
df_casted = df_raw.select(df_raw._c0.cast("int"), *exprs)

df = df_casted.sample(False, .1, seed = 222)

df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: double (nullable = true)
#  |-- _c2: double (nullable = true)
#  |-- _c3: double (nullable = true)
#  |-- _c4: double (nullable = true)
#  |-- _c5: double (nullable = true)
#  |-- _c6: double (nullable = true)
#  |-- _c7: double (nullable = true)
#  |-- _c8: double (nullable = true)
#  |-- _c9: double (nullable = true)
#  |-- _c10: double (nullable = true)
#  |-- _c11: double (nullable = true)
#  |-- _c12: double (nullable = true)

# %%
from pyspark.ml.linalg import DenseVector

# créer un rdd à partir de la df en séparant la colonne à prédire des autres variables 
rdd_ml = df.rdd.map(lambda x: (x[0], DenseVector(x[1:])))

# mettre le rdd sous formt df en nommant les deux colonnes
df_ml = spark.createDataFrame(rdd_ml, ['label', 'features'])

df_ml.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# | 2005|[42.15927,-36.860...|
# | 1997|[40.53094,-23.737...|
# | 2000|[50.76908,29.8401...|
# | 2003|[46.3173,13.03044...|
# | 2009|[49.18434,51.1999...|
# | 2009|[47.48739,43.6001...|
# | 2009|[49.73491,106.182...|
# | 2007|[42.26736,19.4688...|
# | 2007|[45.13814,35.5714...|
# | 2007|[44.85672,25.3150...|
# | 2007|[45.14394,28.8183...|
# | 2004|[48.58166,39.6431...|
# | 2009|[41.53981,12.295,...|
# | 2009|[46.54569,66.5667...|
# | 2009|[43.76116,-11.945...|
# | 2009|[43.667,-20.98101...|
# | 2009|[40.00607,69.8926...|
# | 1991|[31.1901,-98.5275...|
# | 1991|[32.60431,-68.393...|
# | 1991|[28.10519,-105.28...|
# +-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Séparer la BD en deux: train et test

# %%
(train, test) = df_ml.randomSplit([.8, .2], seed = 222)

# %% [markdown]
# ## 1 - Instancier un modèle de régression linéaire

# %%
from pyspark.ml.regression import LinearRegression

# créer la fonction avec les paramètres adaptés
lr = LinearRegression(labelCol='label', featuresCol='features')

# %% [markdown]
# ## 2 - Création d'une grille de paramètres.
#
# Donner à l'algo une grille de paramètres à tester
#
# With 3 values for lr.regParam and 3 values for lr.elasticNetParam,
# this grid will have 3 x 3 = 6 parameter settings for CrossValidator to choose from.

# %%
from pyspark.ml.tuning import ParamGridBuilder

param_grid = ParamGridBuilder().\
        addGrid(lr.regParam, [0, 0.5, 1]).\
        addGrid(lr.elasticNetParam, [0, 0.5, 1]).\
        build()

# %% [markdown]
# ## 3 - Choix d'une métrique d'évaluation

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator = RegressionEvaluator(predictionCol='prediction',
                               labelCol='label',
                               metricName='r2')

# %% [markdown]
# ## 4 - Mise en place d'u cross validator

# %% [markdown]
# Réglage des paramètres par validation croisée (k-fold cross validation)
#
# CrossValidator begins by splitting the dataset into a set of folds which are used as separate training and test datasets. E.g., with k=3 folds, CrossValidator will generate 3 (training, test) dataset pairs, each of which uses 2/3 of the data for training and 1/3 for testing. To evaluate a particular ParamMap, CrossValidator computes the average evaluation metric for the 3 Models produced by fitting the Estimator on the 3 different (training, test) dataset pairs.
#
# After identifying the best ParamMap, CrossValidator finally re-fits the Estimator using the best ParamMap and the entire dataset.
#
# Note that cross-validation over a grid of parameters is expensive. E.g., in our case, the parameter grid has 3 values for lr.elasticNetParam and 3 values for lr.regParam, and CrossValidator uses 3 folds. This multiplies out to (3×3)×3=27 different models being trained.
#
# In realistic settings, it can be common to try many more parameters and use more folds (k=3 and k=10 are common). In other words, using CrossValidator can be very expensive. However, it is also a well-established method for choosing parameters which is more statistically sound than heuristic hand-tuning.

# %%
from pyspark.ml.tuning import CrossValidator

# estimator could be a pipeline
cv = CrossValidator(estimator=lr,
                   estimatorParamMaps=param_grid,
                   evaluator=evaluator,
                   numFolds=3)

# %% [markdown]
#  Run cross-validation, and choose the best set of parameters.

# %%
cv_model = cv.fit(train)

# %% [markdown]
# Make predictions on test documents. cvModel uses the best model found (lrModel).

# %%
pred_train = cv_model.transform(train)

# %%
pred_test = cv_model.transform(test)

# %%
pred_test.show()
# Out:
# +-----+--------------------+------------------+
# |label|            features|        prediction|
# +-----+--------------------+------------------+
# | 1929|[30.44087,-83.073...|1988.6880560508805|
# | 1929|[35.07089,-67.509...|1993.5634458070965|
# | 1929|[38.93054,-58.642...| 1986.886897722553|
# | 1947|[36.61167,-144.91...|1991.6071515232034|
# | 1949|[34.47809,-39.672...|1990.0110155312573|
# | 1952|[43.31663,-11.926...|1992.6652285342857|
# | 1953|[35.44492,-82.151...|1990.6781444410221|
# | 1955|[44.76449,58.0813...|1998.3155282694706|
# | 1956|[34.18681,-72.620...| 1996.954045240956|
# | 1956|[34.6146,-142.972...|1999.9968724985056|
# | 1956|[37.81231,-213.47...|2000.6635685699293|
# | 1956|[37.86685,-69.030...|1999.8380995453879|
# | 1956|[41.0475,-73.6027...|1992.2928622033496|
# | 1956|[42.48217,23.8266...|1989.9725564838072|
# | 1956|[46.16219,-35.359...|1997.2888093918527|
# | 1957|[27.3026,-187.024...|1997.6059132793173|
# | 1957|[27.6883,-29.8628...|1993.5598168315723|
# | 1957|[34.48545,-81.813...|1992.0157368853127|
# | 1959|[25.29724,-165.89...|1999.1553901336272|
# | 1959|[36.51946,-71.555...|1993.9553491698623|
# +-----+--------------------+------------------+
# only showing top 20 rows

# %%
# collect renvoie une liste
selected = pred_test.select("label", "prediction")
for row in selected.collect():
    print(row)
# Out:
# Row(label=1929, prediction=1988.6880560508805)
# Row(label=1929, prediction=1993.5634458070965)
# Row(label=1929, prediction=1986.886897722553)
# Row(label=1947, prediction=1991.6071515232034)
# Row(label=1949, prediction=1990.0110155312573)
# Row(label=1952, prediction=1992.6652285342857)
# Row(label=1953, prediction=1990.6781444410221)
# Row(label=1955, prediction=1998.3155282694706)
# Row(label=1956, prediction=1996.954045240956)
# Row(label=1956, prediction=1999.9968724985056)
# Row(label=1956, prediction=2000.6635685699293)
# Row(label=1956, prediction=1999.8380995453879)
# Row(label=1956, prediction=1992.2928622033496)
# Row(label=1956, prediction=1989.9725564838072)
# Row(label=1956, prediction=1997.2888093918527)
# Row(label=1957, prediction=1997.6059132793173)
# Row(label=1957, prediction=1993.5598168315723)
# Row(label=1957, prediction=1992.0157368853127)
# Row(label=1959, prediction=1999.1553901336272)
# Row(label=1959, prediction=1993.9553491698623)
# Row(label=1959, prediction=1995.5810786355073)
# Row(label=1959, prediction=1995.986714254567)
# Row(label=1960, prediction=1984.627005460215)
# Row(label=1960, prediction=1994.5614755837853)
# Row(label=1960, prediction=1995.3098632145525)
# Row(label=1960, prediction=1996.0966952982174)
# Row(label=1960, prediction=2000.932446978968)
# Row(label=1961, prediction=1993.2945761338644)
# Row(label=1962, prediction=1994.6151144056646)
# Row(label=1962, prediction=1991.7368644019054)
# Row(label=1962, prediction=1991.7228585006133)
# Row(label=1962, prediction=1989.4162220604671)
# Row(label=1963, prediction=1992.1173141566148)
# Row(label=1963, prediction=1996.29439805926)
# Row(label=1964, prediction=1992.8532629102074)
# Row(label=1964, prediction=1993.510543139416)
# Row(label=1964, prediction=1999.9784032460345)
# Row(label=1965, prediction=1990.9841098265517)
# Row(label=1965, prediction=1992.1212552370105)
# Row(label=1965, prediction=1992.173360331491)
# Row(label=1965, prediction=1993.8849621345378)
# Row(label=1965, prediction=1990.4820906160421)
# Row(label=1965, prediction=2006.1168521560865)
# Row(label=1965, prediction=1996.1369835033156)
# Row(label=1965, prediction=1997.8735600338425)
# Row(label=1966, prediction=1996.6346960510418)
# Row(label=1966, prediction=1997.744804404634)
# Row(label=1966, prediction=1992.65640966035)
# Row(label=1966, prediction=1994.5343778633608)
# Row(label=1966, prediction=1996.7449768038591)
# Row(label=1966, prediction=1993.2413003582042)
# Row(label=1966, prediction=1999.890453560568)
# Row(label=1966, prediction=1997.338614231426)
# Row(label=1966, prediction=1993.593720132657)
# Row(label=1966, prediction=1994.9354450741466)
# Row(label=1966, prediction=1997.0518678113744)
# Row(label=1966, prediction=1996.2666099474188)
# Row(label=1967, prediction=1983.4885201524733)
# Row(label=1967, prediction=1995.6466450468151)
# Row(label=1967, prediction=1994.0803400890666)
# Row(label=1967, prediction=1994.309576639373)
# Row(label=1967, prediction=1993.627169817612)
# Row(label=1967, prediction=1994.3175617069116)
# Row(label=1967, prediction=1996.1644220630374)
# Row(label=1967, prediction=1998.018811757032)
# Row(label=1967, prediction=1995.8168371593456)
# Row(label=1968, prediction=1994.2565536887705)
# Row(label=1968, prediction=1991.9367045138863)
# Row(label=1968, prediction=1996.786455197463)
# Row(label=1968, prediction=1994.3625333533969)
# Row(label=1968, prediction=1993.8984499359844)
# Row(label=1969, prediction=1993.729252142297)
# Row(label=1969, prediction=1998.9825789051413)
# Row(label=1969, prediction=1990.5659588719216)
# Row(label=1969, prediction=1997.29204799121)
# Row(label=1969, prediction=1999.0479851873615)
# Row(label=1969, prediction=1994.5831029083631)
# Row(label=1969, prediction=1994.3732665869807)
# Row(label=1969, prediction=1995.1568659734316)
# Row(label=1969, prediction=1995.2939106227782)
# Row(label=1969, prediction=1999.3626551215723)
# Row(label=1969, prediction=2001.7494171630378)
# Row(label=1970, prediction=1994.729484845334)
# Row(label=1970, prediction=1991.847181188412)
# Row(label=1970, prediction=1990.8445789864531)
# Row(label=1970, prediction=1996.77536118982)
# Row(label=1970, prediction=1985.9697292035212)
# Row(label=1970, prediction=1995.337361488214)
# Row(label=1970, prediction=1996.662600001611)
# Row(label=1970, prediction=1989.0529553776744)
# Row(label=1970, prediction=1993.8317549880376)
# Row(label=1970, prediction=1995.1427717803642)
# Row(label=1970, prediction=1998.282860980991)
# Row(label=1970, prediction=2001.0327452588624)
# Row(label=1970, prediction=1998.601499746828)
# Row(label=1970, prediction=1999.300785477)
# Row(label=1971, prediction=1988.7469851687142)
# Row(label=1971, prediction=1994.7965548758011)
# Row(label=1971, prediction=1989.4492020843725)
# Row(label=1971, prediction=1993.6592032637677)
# Row(label=1971, prediction=1995.9955740019598)
# Row(label=1971, prediction=1990.912638039672)
# Row(label=1971, prediction=2002.595241602062)
# Row(label=1971, prediction=1996.1180522960474)
# Row(label=1971, prediction=1997.0917343250508)
# Row(label=1971, prediction=1996.1500241565025)
# Row(label=1971, prediction=1994.607978098976)
# Row(label=1972, prediction=1990.1962978945705)
# Row(label=1972, prediction=1996.1040155429882)
# Row(label=1972, prediction=1995.2198591449283)
# Row(label=1972, prediction=1992.238106879478)
# Row(label=1972, prediction=1996.031703031628)
# Row(label=1972, prediction=1987.979733626804)
# Row(label=1972, prediction=1991.383550276591)
# Row(label=1972, prediction=1991.8542063496482)
# Row(label=1972, prediction=1998.8764642030867)
# Row(label=1972, prediction=1998.0052577330152)
# Row(label=1972, prediction=1998.8129949553531)
# Row(label=1973, prediction=1990.4127638119967)
# Row(label=1973, prediction=1981.9421305229885)
# Row(label=1973, prediction=1992.742112630077)
# Row(label=1973, prediction=1995.618117275523)
# Row(label=1973, prediction=1994.8491850610574)
# Row(label=1973, prediction=1991.0849963235153)
# Row(label=1973, prediction=1995.021323377559)
# Row(label=1973, prediction=1996.0955094151204)
# Row(label=1973, prediction=1995.930721663097)
# Row(label=1973, prediction=1990.484517330906)
# Row(label=1973, prediction=1998.6530636283965)
# Row(label=1973, prediction=1998.1732704414824)
# Row(label=1973, prediction=1996.1373077760136)
# Row(label=1973, prediction=1995.4696915902773)
# Row(label=1973, prediction=1998.4709907909078)
# Row(label=1973, prediction=1993.65111255101)
# Row(label=1973, prediction=1997.8713605436003)
# Row(label=1974, prediction=1992.2789666494436)
# Row(label=1974, prediction=1998.0058354045832)
# Row(label=1974, prediction=1994.726043650398)
# Row(label=1974, prediction=1995.5373863117038)
# Row(label=1974, prediction=1995.721198048756)
# Row(label=1974, prediction=1994.1845987358633)
# Row(label=1974, prediction=1995.0185444219567)
# Row(label=1974, prediction=1996.5389728483296)
# Row(label=1974, prediction=2000.6373285272175)
# Row(label=1974, prediction=1998.3373756918302)
# Row(label=1975, prediction=1988.5741788820892)
# Row(label=1975, prediction=1993.5987522486978)
# Row(label=1975, prediction=1994.3063512225265)
# Row(label=1975, prediction=1989.5247404449412)
# Row(label=1975, prediction=1992.3736246771794)
# Row(label=1975, prediction=1991.52073437718)
# Row(label=1975, prediction=1998.4156525614878)
# Row(label=1975, prediction=1995.4737580408673)
# Row(label=1975, prediction=1996.0987818250323)
# Row(label=1975, prediction=1989.4921857226739)
# Row(label=1975, prediction=1990.0968638437669)
# Row(label=1975, prediction=1995.5797010729386)
# Row(label=1975, prediction=1992.8595498413686)
# Row(label=1975, prediction=1994.616308489579)
# Row(label=1975, prediction=1992.6848362916767)
# Row(label=1975, prediction=1994.379006244166)
# Row(label=1975, prediction=1997.1697649094451)
# Row(label=1976, prediction=1989.0632820487774)
# Row(label=1976, prediction=1999.7950044454715)
# Row(label=1976, prediction=1991.700403707944)
# Row(label=1976, prediction=1986.92079607824)
# Row(label=1976, prediction=1995.0938880610252)
# Row(label=1976, prediction=1997.0096694097106)
# Row(label=1976, prediction=1990.3681229131907)
# Row(label=1976, prediction=1991.0048227776)
# Row(label=1976, prediction=1996.3664508085894)
# Row(label=1976, prediction=1991.373779645965)
# Row(label=1976, prediction=1993.9110630128537)
# Row(label=1976, prediction=1996.1031732289555)
# Row(label=1976, prediction=1998.10093771454)
# Row(label=1976, prediction=1995.8640252463952)
# Row(label=1976, prediction=2000.1295416941184)
# Row(label=1976, prediction=2004.9307516925376)
# Row(label=1976, prediction=1997.029718576241)
# Row(label=1976, prediction=1995.307051990197)
# Row(label=1976, prediction=1998.4190543654036)
# Row(label=1976, prediction=1998.8148728792244)
# Row(label=1977, prediction=1990.5196739449116)
# Row(label=1977, prediction=1989.4253027103587)
# Row(label=1977, prediction=1990.250144776256)
# Row(label=1977, prediction=1995.2586066097533)
# Row(label=1977, prediction=1994.6509110528702)
# Row(label=1977, prediction=1996.1566506980662)
# Row(label=1977, prediction=1996.539045025374)
# Row(label=1977, prediction=1992.0844546449448)
# Row(label=1977, prediction=1998.0029088385938)
# Row(label=1977, prediction=1999.911785533295)
# Row(label=1977, prediction=1994.2250833305516)
# Row(label=1977, prediction=2003.0403483157563)
# Row(label=1977, prediction=1991.9390320787431)
# Row(label=1977, prediction=1994.7724487973828)
# Row(label=1977, prediction=1997.7066550923917)
# Row(label=1977, prediction=2002.6033795252476)
# Row(label=1978, prediction=1993.2000134182285)
# Row(label=1978, prediction=1997.9917529028353)
# Row(label=1978, prediction=1995.5224151831583)
# Row(label=1978, prediction=1997.1382096754612)
# Row(label=1978, prediction=1998.0869131560532)
# Row(label=1978, prediction=1992.066501596694)
# Row(label=1978, prediction=1994.1762800807153)
# Row(label=1978, prediction=1996.7091293434028)
# Row(label=1979, prediction=1996.989407872916)
# Row(label=1979, prediction=1986.5549228606242)
# Row(label=1979, prediction=1993.4022262548372)
# Row(label=1979, prediction=1988.719667334993)
# Row(label=1979, prediction=1997.198080455288)
# Row(label=1979, prediction=1993.3244942513152)
# Row(label=1979, prediction=1994.0762259664834)
# Row(label=1979, prediction=1995.0445472291692)
# Row(label=1979, prediction=1991.733248276642)
# Row(label=1979, prediction=1999.968653588201)
# Row(label=1979, prediction=1995.1982068103518)
# Row(label=1979, prediction=1994.0003050767696)
# Row(label=1979, prediction=2003.9299465459878)
# Row(label=1979, prediction=1997.972102378514)
# Row(label=1979, prediction=2001.85547613975)
# Row(label=1979, prediction=2001.0009089193532)
# Row(label=1980, prediction=1999.9318225257732)
# Row(label=1980, prediction=1995.6743328637667)
# Row(label=1980, prediction=1994.422439613637)
# Row(label=1980, prediction=1992.2852853909403)
# Row(label=1980, prediction=1998.7008794427052)
# Row(label=1980, prediction=1994.865091299924)
# Row(label=1980, prediction=1994.4615356265208)
# Row(label=1980, prediction=2002.6889538168134)
# Row(label=1980, prediction=2001.9725474354357)
# Row(label=1980, prediction=1996.4709080106254)
# Row(label=1980, prediction=1999.5503385242066)
# Row(label=1980, prediction=1998.1913130991286)
# Row(label=1980, prediction=1996.280280716395)
# Row(label=1980, prediction=1996.7447255833997)
# Row(label=1980, prediction=1995.3512824621464)
# Row(label=1980, prediction=1998.1407247667646)
# Row(label=1980, prediction=1997.2402055856185)
# Row(label=1980, prediction=2002.9077744514548)
# Row(label=1981, prediction=2000.617230267944)
# Row(label=1981, prediction=1994.2984429409064)
# Row(label=1981, prediction=1992.3709625027097)
# Row(label=1981, prediction=1989.5412432862622)
# Row(label=1981, prediction=1992.3579135539842)
# Row(label=1981, prediction=1992.1904222504268)
# Row(label=1981, prediction=1991.6042546246265)
# Row(label=1981, prediction=1995.5966796150453)
# Row(label=1981, prediction=1994.7567199745479)
# Row(label=1981, prediction=1995.1223060672867)
# Row(label=1981, prediction=1993.4774922110314)
# Row(label=1981, prediction=1997.6406700140235)
# Row(label=1981, prediction=1993.9060458509277)
# Row(label=1981, prediction=1995.127915159709)
# Row(label=1981, prediction=1994.9669961975692)
# Row(label=1981, prediction=1991.3937258334863)
# Row(label=1981, prediction=1990.644912876081)
# Row(label=1981, prediction=1998.855381439169)
# Row(label=1981, prediction=2002.606486757472)
# Row(label=1981, prediction=1997.619024985172)
# Row(label=1981, prediction=1998.3223179321576)
# Row(label=1981, prediction=2000.922651049523)
# Row(label=1981, prediction=2001.631341605956)
# Row(label=1981, prediction=2000.5005646193688)
# Row(label=1981, prediction=2002.9319551765993)
# Row(label=1981, prediction=2000.8010285374419)
# Row(label=1982, prediction=1983.5959125961447)
# Row(label=1982, prediction=1999.3516215964178)
# Row(label=1982, prediction=1994.110933847013)
# Row(label=1982, prediction=1995.9922506721632)
# Row(label=1982, prediction=1994.7758188005544)
# Row(label=1982, prediction=1999.6937374939705)
# Row(label=1982, prediction=1997.5193217435842)
# Row(label=1982, prediction=1994.6430936236832)
# Row(label=1982, prediction=1998.6410632219345)
# Row(label=1982, prediction=1996.0144115641876)
# Row(label=1982, prediction=1997.1959241728764)
# Row(label=1982, prediction=1999.2841964386034)
# Row(label=1982, prediction=2002.9927002941708)
# Row(label=1982, prediction=1997.039100403585)
# Row(label=1982, prediction=1997.7916141104533)
# Row(label=1982, prediction=2002.0822530608414)
# Row(label=1982, prediction=1999.5347193227149)
# Row(label=1983, prediction=1990.6057393658814)
# Row(label=1983, prediction=1995.4006744897274)
# Row(label=1983, prediction=1989.425032259765)
# Row(label=1983, prediction=1994.0212949095876)
# Row(label=1983, prediction=1992.7383361264317)
# Row(label=1983, prediction=1995.061565760915)
# Row(label=1983, prediction=1992.8340532138511)
# Row(label=1983, prediction=1993.8374331168247)
# Row(label=1983, prediction=1994.277386510444)
# Row(label=1983, prediction=1991.963436374605)
# Row(label=1983, prediction=1996.6061905019858)
# Row(label=1983, prediction=1996.5496351353127)
# Row(label=1983, prediction=1994.7378398710625)
# Row(label=1983, prediction=1999.276957118046)
# Row(label=1983, prediction=1997.8339315828493)
# Row(label=1983, prediction=1997.76887027502)
# Row(label=1983, prediction=2001.0516587838056)
# Row(label=1984, prediction=1981.800420749791)
# Row(label=1984, prediction=1993.4027653891058)
# Row(label=1984, prediction=1990.4177915309274)
# Row(label=1984, prediction=1990.9762578548057)
# Row(label=1984, prediction=1992.5235844614608)
# Row(label=1984, prediction=1993.5283540150265)
# Row(label=1984, prediction=1993.6008257725957)
# Row(label=1984, prediction=1994.7258854384406)
# Row(label=1984, prediction=1996.598489897991)
# Row(label=1984, prediction=1995.4301063063806)
# Row(label=1984, prediction=1995.193587445069)
# Row(label=1984, prediction=2001.17880464959)
# Row(label=1984, prediction=1998.5542285262463)
# Row(label=1984, prediction=2003.1162155957763)
# Row(label=1985, prediction=1995.5681177151823)
# Row(label=1985, prediction=1991.2548777337595)
# Row(label=1985, prediction=1993.8877000419518)
# Row(label=1985, prediction=1995.2079934720575)
# Row(label=1985, prediction=1992.4068360086194)
# Row(label=1985, prediction=1997.9594656260542)
# Row(label=1985, prediction=1994.9739425780483)
# Row(label=1985, prediction=2001.1942527848491)
# Row(label=1985, prediction=2002.6033914931754)
# Row(label=1986, prediction=1991.360676621247)
# Row(label=1986, prediction=1989.631930784926)
# Row(label=1986, prediction=1996.536682844785)
# Row(label=1986, prediction=1997.5943664765878)
# Row(label=1986, prediction=1993.4896884798509)
# Row(label=1986, prediction=1992.6355032737592)
# Row(label=1986, prediction=1990.7766723746254)
# Row(label=1986, prediction=1994.092478904336)
# Row(label=1986, prediction=1994.4137159988609)
# Row(label=1986, prediction=1993.591745043857)
# Row(label=1986, prediction=1993.610547642291)
# Row(label=1986, prediction=1996.1334977723359)
# Row(label=1986, prediction=1995.1770665001081)
# Row(label=1986, prediction=1994.5003858936634)
# Row(label=1986, prediction=1997.4529875751634)
# Row(label=1986, prediction=1996.1167760269705)
# Row(label=1986, prediction=1993.4851206945668)
# Row(label=1986, prediction=1995.7216992206515)
# Row(label=1986, prediction=2001.8174295959175)
# Row(label=1986, prediction=2002.3388912101818)
# Row(label=1986, prediction=1994.989705332466)
# Row(label=1986, prediction=1999.9143466137878)
# Row(label=1986, prediction=1996.2119971775405)
# Row(label=1986, prediction=2003.3218553053734)
# Row(label=1987, prediction=1996.4000123249302)
# Row(label=1987, prediction=1994.1307207804573)
# Row(label=1987, prediction=1987.5263365251321)
# Row(label=1987, prediction=1999.026773597481)
# Row(label=1987, prediction=1988.5036089718533)
# Row(label=1987, prediction=1993.481142197081)
# Row(label=1987, prediction=2003.2008687938119)
# Row(label=1987, prediction=1993.7069394069222)
# Row(label=1987, prediction=1991.8834863186082)
# Row(label=1987, prediction=1994.459936408598)
# Row(label=1987, prediction=1995.8221250603676)
# Row(label=1987, prediction=1989.3443121412595)
# Row(label=1987, prediction=1992.6341777515588)
# Row(label=1987, prediction=1996.9809440990625)
# Row(label=1987, prediction=1996.8259154922387)
# Row(label=1987, prediction=1995.5277661019759)
# Row(label=1987, prediction=1995.2231317817552)
# Row(label=1987, prediction=1991.753643094026)
# Row(label=1987, prediction=1997.6458797650648)
# Row(label=1987, prediction=1996.3318000752001)
# Row(label=1987, prediction=1991.2058008302809)
# Row(label=1987, prediction=1994.3428431436262)
# Row(label=1987, prediction=1994.873352414747)
# Row(label=1987, prediction=1994.8470012300436)
# Row(label=1987, prediction=2003.5958260843995)
# Row(label=1987, prediction=1998.0740144664455)
# Row(label=1987, prediction=1991.3024532318973)
# Row(label=1987, prediction=1991.0642292179684)
# Row(label=1987, prediction=2007.6174734621572)
# Row(label=1988, prediction=1988.1077960687653)
# Row(label=1988, prediction=1988.1892811839039)
# Row(label=1988, prediction=1996.6719773553516)
# Row(label=1988, prediction=1990.6501321877583)
# Row(label=1988, prediction=1993.899881971457)
# Row(label=1988, prediction=1993.7208253361391)
# Row(label=1988, prediction=1994.5987416424603)
# Row(label=1988, prediction=1995.2698903784024)
# Row(label=1988, prediction=1994.1382726988454)
# Row(label=1988, prediction=1995.27024141651)
# Row(label=1988, prediction=1994.947125181386)
# Row(label=1988, prediction=1996.85238172457)
# Row(label=1988, prediction=1992.2483027824985)
# Row(label=1988, prediction=1997.0785489976672)
# Row(label=1988, prediction=1995.7935167395958)
# Row(label=1988, prediction=1994.8687881041571)
# Row(label=1988, prediction=1993.7187479743752)
# Row(label=1988, prediction=2003.5989459893067)
# Row(label=1988, prediction=1996.7589797518349)
# Row(label=1988, prediction=1995.3530734768622)
# Row(label=1988, prediction=1997.2263619079308)
# Row(label=1988, prediction=1997.048101205751)
# Row(label=1988, prediction=1996.1699494944044)
# Row(label=1988, prediction=1997.3372861883863)
# Row(label=1988, prediction=1999.2364099453928)
# Row(label=1988, prediction=1997.1565506515642)
# Row(label=1988, prediction=1993.8886627107333)
# Row(label=1988, prediction=1997.0942984149729)
# Row(label=1988, prediction=1995.844741443205)
# Row(label=1988, prediction=1999.575084656959)
# Row(label=1988, prediction=1999.1716029307934)
# Row(label=1988, prediction=2000.7048639311413)
# Row(label=1989, prediction=1994.9185891183497)
# Row(label=1989, prediction=1991.4380967636555)
# Row(label=1989, prediction=1987.8051591479832)
# Row(label=1989, prediction=1988.5669630694101)
# Row(label=1989, prediction=1992.8545419297216)
# Row(label=1989, prediction=1992.4674932147252)
# Row(label=1989, prediction=1993.1263831802623)
# Row(label=1989, prediction=1995.312398001426)
# Row(label=1989, prediction=1999.3040018030074)
# Row(label=1989, prediction=1993.760778921858)
# Row(label=1989, prediction=1995.492876218124)
# Row(label=1989, prediction=1998.8106048756918)
# Row(label=1989, prediction=1995.6275747734735)
# Row(label=1989, prediction=1993.975094069332)
# Row(label=1989, prediction=1992.826642878738)
# Row(label=1989, prediction=1994.4129960943678)
# Row(label=1989, prediction=1995.5916631366847)
# Row(label=1989, prediction=1997.9824396901272)
# Row(label=1989, prediction=1996.2586718272541)
# Row(label=1989, prediction=1996.3644766437924)
# Row(label=1989, prediction=1993.0717908236973)
# Row(label=1989, prediction=1996.4713021914972)
# Row(label=1989, prediction=1997.9058781033455)
# Row(label=1989, prediction=1997.4475915524147)
# Row(label=1989, prediction=1999.154685021397)
# Row(label=1989, prediction=2000.2326694883986)
# Row(label=1989, prediction=2000.2075081770195)
# Row(label=1989, prediction=1999.429972046829)
# Row(label=1989, prediction=1997.1167637277156)
# Row(label=1989, prediction=2001.4356060855646)
# Row(label=1990, prediction=1997.934736544461)
# Row(label=1990, prediction=1989.7951375629375)
# Row(label=1990, prediction=1997.689485727105)
# Row(label=1990, prediction=1990.1179058250625)
# Row(label=1990, prediction=1988.8838769596398)
# Row(label=1990, prediction=1999.3876214055174)
# Row(label=1990, prediction=1988.672973174585)
# Row(label=1990, prediction=1994.9848749242337)
# Row(label=1990, prediction=1994.3167396326107)
# Row(label=1990, prediction=1993.6654171191738)
# Row(label=1990, prediction=1993.8442651260727)
# Row(label=1990, prediction=1995.8903597852516)
# Row(label=1990, prediction=1995.5187054181292)
# Row(label=1990, prediction=1996.8416271225612)
# Row(label=1990, prediction=1993.0384890269477)
# Row(label=1990, prediction=1999.9840124182467)
# Row(label=1990, prediction=1990.4737223511895)
# Row(label=1990, prediction=1992.3414394452307)
# Row(label=1990, prediction=1992.868536222475)
# Row(label=1990, prediction=1995.3414118129408)
# Row(label=1990, prediction=1995.633668206384)
# Row(label=1990, prediction=2000.883044939532)
# Row(label=1990, prediction=1997.1634529729536)
# Row(label=1990, prediction=1996.4184803713683)
# Row(label=1990, prediction=1992.958069392383)
# Row(label=1990, prediction=1991.7601180955517)
# Row(label=1990, prediction=1995.9179758551477)
# Row(label=1990, prediction=1997.1930214857514)
# Row(label=1990, prediction=1995.7669104057384)
# Row(label=1990, prediction=2002.6080085107587)
# Row(label=1990, prediction=2002.8847106292953)
# Row(label=1990, prediction=1998.1477003238722)
# Row(label=1990, prediction=1999.6499646382185)
# Row(label=1990, prediction=1999.3863950180605)
# Row(label=1990, prediction=2001.8409339284958)
# Row(label=1990, prediction=2000.0364958448936)
# Row(label=1991, prediction=1984.7628235394898)
# Row(label=1991, prediction=1993.7436259187198)
# Row(label=1991, prediction=1989.7135659857695)
# Row(label=1991, prediction=1996.005141588692)
# Row(label=1991, prediction=1995.0054523537244)
# Row(label=1991, prediction=1998.1173723357101)
# Row(label=1991, prediction=1999.392348975655)
# Row(label=1991, prediction=1992.5722471808836)
# Row(label=1991, prediction=1994.774234036095)
# Row(label=1991, prediction=1992.3092118981463)
# Row(label=1991, prediction=1995.5541380263717)
# Row(label=1991, prediction=1998.9464631406074)
# Row(label=1991, prediction=1995.704335080371)
# Row(label=1991, prediction=1996.2273591552162)
# Row(label=1991, prediction=2003.0977382280355)
# Row(label=1991, prediction=1994.5938619996843)
# Row(label=1991, prediction=1996.0718619611544)
# Row(label=1991, prediction=1994.4617469913997)
# Row(label=1991, prediction=1993.648515757076)
# Row(label=1991, prediction=1998.0070557172712)
# Row(label=1991, prediction=1990.3032205911413)
# Row(label=1991, prediction=1997.5501298549216)
# Row(label=1991, prediction=1996.1086093544247)
# Row(label=1991, prediction=1988.8969242237551)
# Row(label=1991, prediction=2000.469215650154)
# Row(label=1991, prediction=1996.363639845437)
# Row(label=1991, prediction=2001.7194643042355)
# Row(label=1991, prediction=1995.6171367074317)
# Row(label=1991, prediction=2001.3760073541966)
# Row(label=1991, prediction=1996.99399835705)
# Row(label=1991, prediction=1994.272002185241)
# Row(label=1991, prediction=1998.820396943346)
# Row(label=1991, prediction=1997.2648666755026)
# Row(label=1991, prediction=1996.6446486114112)
# Row(label=1991, prediction=2003.6452392865442)
# Row(label=1991, prediction=2000.7245368957297)
# Row(label=1991, prediction=2002.9916998493113)
# Row(label=1991, prediction=2004.4316466900968)
# Row(label=1992, prediction=1984.8926759093233)
# Row(label=1992, prediction=1992.7820386970807)
# Row(label=1992, prediction=1995.0260558710688)
# Row(label=1992, prediction=1994.5276555198027)
# Row(label=1992, prediction=1981.2212636891893)
# Row(label=1992, prediction=1992.6290391340156)
# Row(label=1992, prediction=1997.8410308686568)
# Row(label=1992, prediction=1996.1967748495772)
# Row(label=1992, prediction=2001.1667581735462)
# Row(label=1992, prediction=1994.1076580263277)
# Row(label=1992, prediction=1994.8082947449604)
# Row(label=1992, prediction=1991.519261490802)
# Row(label=1992, prediction=1992.656896339083)
# Row(label=1992, prediction=1996.0374217119947)
# Row(label=1992, prediction=1990.1947194325724)
# Row(label=1992, prediction=1991.475806183886)
# Row(label=1992, prediction=1996.0191416108896)
# Row(label=1992, prediction=1994.469410505296)
# Row(label=1992, prediction=1996.6657363329302)
# Row(label=1992, prediction=1995.0353534851595)
# Row(label=1992, prediction=1996.0350606433742)
# Row(label=1992, prediction=1994.7316316538142)
# Row(label=1992, prediction=1997.6117656770264)
# Row(label=1992, prediction=1992.5379493915489)
# Row(label=1992, prediction=1986.346446966012)
# Row(label=1992, prediction=1998.729346318553)
# Row(label=1992, prediction=1998.5168484456508)
# Row(label=1992, prediction=1997.9706327835866)
# Row(label=1992, prediction=1997.4100353043052)
# Row(label=1992, prediction=1991.4962387899898)
# Row(label=1992, prediction=1993.8998600815846)
# Row(label=1992, prediction=1993.089416831919)
# Row(label=1992, prediction=1994.5236182586532)
# Row(label=1992, prediction=2000.1469671586754)
# Row(label=1992, prediction=1997.5353827992612)
# Row(label=1992, prediction=1999.2690384033144)
# Row(label=1992, prediction=1999.3240062402058)
# Row(label=1992, prediction=1999.4337017190433)
# Row(label=1992, prediction=1998.5213322673872)
# Row(label=1992, prediction=1993.1815378899132)
# Row(label=1992, prediction=1995.7959573414105)
# Row(label=1992, prediction=1995.2613864420787)
# Row(label=1992, prediction=1995.5936263286605)
# Row(label=1992, prediction=2002.0420134434094)
# Row(label=1992, prediction=2000.4059892661178)
# Row(label=1992, prediction=2000.470237063352)
# Row(label=1992, prediction=1998.240003898601)
# Row(label=1992, prediction=1998.7928257692495)
# Row(label=1992, prediction=1994.7138053847505)
# Row(label=1992, prediction=1990.505059318631)
# Row(label=1992, prediction=1994.9933263492649)
# Row(label=1992, prediction=1996.1041419886333)
# Row(label=1992, prediction=1997.7489888977473)
# Row(label=1992, prediction=2000.258390420549)
# Row(label=1992, prediction=2000.1418052971826)
# Row(label=1992, prediction=1999.6451775281826)
# Row(label=1992, prediction=1999.689625360747)
# Row(label=1992, prediction=2002.2655192183192)
# Row(label=1993, prediction=1992.0506562610494)
# Row(label=1993, prediction=1992.6706251437151)
# Row(label=1993, prediction=1988.2735359272708)
# Row(label=1993, prediction=1992.9365831192515)
# Row(label=1993, prediction=1995.0527577445444)
# Row(label=1993, prediction=1996.6231461830744)
# Row(label=1993, prediction=1992.7432324602182)
# Row(label=1993, prediction=1993.0198844129575)
# Row(label=1993, prediction=1996.9897012451077)
# Row(label=1993, prediction=1992.9641026234726)
# Row(label=1993, prediction=1994.910824143348)
# Row(label=1993, prediction=1995.0400556363195)
# Row(label=1993, prediction=1995.9680202243849)
# Row(label=1993, prediction=1994.6828169442397)
# Row(label=1993, prediction=2004.1206316946848)
# Row(label=1993, prediction=1995.1586738345766)
# Row(label=1993, prediction=1996.78931671175)
# Row(label=1993, prediction=1993.5047668918671)
# Row(label=1993, prediction=1995.8579243621818)
# Row(label=1993, prediction=1993.671886017131)
# Row(label=1993, prediction=1998.4204698345025)
# Row(label=1993, prediction=1997.0643742038997)
# Row(label=1993, prediction=1997.4241042436574)
# Row(label=1993, prediction=1995.5007351710735)
# Row(label=1993, prediction=1998.2245570074936)
# Row(label=1993, prediction=1996.7686444478345)
# Row(label=1993, prediction=1994.7255436409753)
# Row(label=1993, prediction=1996.4162528054608)
# Row(label=1993, prediction=2000.937837674239)
# Row(label=1993, prediction=1998.0103038125749)
# Row(label=1993, prediction=1997.0169199398456)
# Row(label=1993, prediction=1996.2081257916104)
# Row(label=1993, prediction=2000.2384960188595)
# Row(label=1993, prediction=1997.2583003182724)
# Row(label=1993, prediction=1999.0486116977581)
# Row(label=1993, prediction=2000.3618472399312)
# Row(label=1993, prediction=1993.467786502251)
# Row(label=1993, prediction=2001.1308217526257)
# Row(label=1993, prediction=1997.3662684708045)
# Row(label=1993, prediction=2001.512321590139)
# Row(label=1993, prediction=1993.7196518279732)
# Row(label=1993, prediction=2000.9492373270996)
# Row(label=1993, prediction=1995.3328467963545)
# Row(label=1993, prediction=2000.7832981239253)
# Row(label=1993, prediction=2001.8410420809682)
# Row(label=1993, prediction=1999.3876538313568)
# Row(label=1993, prediction=1996.911212539811)
# Row(label=1993, prediction=1998.8949914862749)
# Row(label=1993, prediction=1998.802200361812)
# Row(label=1993, prediction=2004.1177788083726)
# Row(label=1993, prediction=2002.7420457432306)
# Row(label=1993, prediction=2001.863464999292)
# Row(label=1993, prediction=2003.5208677628293)
# Row(label=1994, prediction=1988.6174051690004)
# Row(label=1994, prediction=1985.988009713801)
# Row(label=1994, prediction=1995.493218078674)
# Row(label=1994, prediction=1993.9763556197267)
# Row(label=1994, prediction=1990.4486309002832)
# Row(label=1994, prediction=1986.6784863648777)
# Row(label=1994, prediction=1992.1937596389785)
# Row(label=1994, prediction=1990.5856674776792)
# Row(label=1994, prediction=1993.6835256932482)
# Row(label=1994, prediction=1989.7038650123502)
# Row(label=1994, prediction=1988.1097212606157)
# Row(label=1994, prediction=1998.2168718420512)
# Row(label=1994, prediction=1999.2012106709194)
# Row(label=1994, prediction=1994.1868218585607)
# Row(label=1994, prediction=1990.880430726471)
# Row(label=1994, prediction=1996.6105897801137)
# Row(label=1994, prediction=1996.5375332387991)
# Row(label=1994, prediction=1996.7098280391847)
# Row(label=1994, prediction=1997.1233538110955)
# Row(label=1994, prediction=2009.9705851713004)
# Row(label=1994, prediction=1994.6181957097097)
# Row(label=1994, prediction=1996.693325857039)
# Row(label=1994, prediction=1994.9717125812144)
# Row(label=1994, prediction=1994.8928883800418)
# Row(label=1994, prediction=2004.4706217184141)
# Row(label=1994, prediction=1995.4107107699951)
# Row(label=1994, prediction=1996.244887126136)
# Row(label=1994, prediction=1997.2695084843465)
# Row(label=1994, prediction=1987.764813209228)
# Row(label=1994, prediction=1999.9136957594965)
# Row(label=1994, prediction=1996.319761721786)
# Row(label=1994, prediction=1991.8946786262884)
# Row(label=1994, prediction=1989.7960969684113)
# Row(label=1994, prediction=1995.9918421825312)
# Row(label=1994, prediction=1997.1968757106436)
# Row(label=1994, prediction=1995.4036898747554)
# Row(label=1994, prediction=1997.8127690048755)
# Row(label=1994, prediction=1997.199581987599)
# Row(label=1994, prediction=1993.2911337324963)
# Row(label=1994, prediction=1999.263699237911)
# Row(label=1994, prediction=1994.9765159509757)
# Row(label=1994, prediction=1998.929665776048)
# Row(label=1994, prediction=1998.469095065186)
# Row(label=1994, prediction=1999.4857110134215)
# Row(label=1994, prediction=1997.5272099814936)
# Row(label=1994, prediction=1996.4775789744538)
# Row(label=1994, prediction=1995.127977837759)
# Row(label=1994, prediction=1995.5114150915856)
# Row(label=1994, prediction=1996.4856377989768)
# Row(label=1994, prediction=1999.3353333125497)
# Row(label=1994, prediction=1997.4869722274289)
# Row(label=1994, prediction=1999.6540960909363)
# Row(label=1994, prediction=1994.8759003044784)
# Row(label=1994, prediction=1999.3601464308163)
# Row(label=1994, prediction=2004.0851801305691)
# Row(label=1994, prediction=1994.8524532527688)
# Row(label=1994, prediction=1997.662441451161)
# Row(label=1994, prediction=1998.2097821696034)
# Row(label=1994, prediction=2002.6607122067385)
# Row(label=1994, prediction=2000.458386100389)
# Row(label=1995, prediction=2000.1871195213535)
# Row(label=1995, prediction=1986.4382497052381)
# Row(label=1995, prediction=1990.9524150848074)
# Row(label=1995, prediction=1993.9549636710503)
# Row(label=1995, prediction=1986.3804494014707)
# Row(label=1995, prediction=1991.938200599561)
# Row(label=1995, prediction=2001.7940572107536)
# Row(label=1995, prediction=1989.9383969867945)
# Row(label=1995, prediction=1996.8716362907228)
# Row(label=1995, prediction=1992.6145398456565)
# Row(label=1995, prediction=1995.4790119967568)
# Row(label=1995, prediction=1999.5961267097907)
# Row(label=1995, prediction=1992.5701301709641)
# Row(label=1995, prediction=1994.9453930079217)
# Row(label=1995, prediction=1994.9056799346731)
# Row(label=1995, prediction=1994.012980783914)
# Row(label=1995, prediction=1992.237101540562)
# Row(label=1995, prediction=2006.8129778953407)
# Row(label=1995, prediction=1989.2833895945864)
# Row(label=1995, prediction=1989.8386474477818)
# Row(label=1995, prediction=1994.5610727848032)
# Row(label=1995, prediction=1998.2798474247402)
# Row(label=1995, prediction=1994.6895666421235)
# Row(label=1995, prediction=1996.739379920404)
# Row(label=1995, prediction=1993.5508032546327)
# Row(label=1995, prediction=1999.5500731319676)
# Row(label=1995, prediction=1995.7652401573323)
# Row(label=1995, prediction=1996.1822612681108)
# Row(label=1995, prediction=1997.81428776188)
# Row(label=1995, prediction=1995.3264996018063)
# Row(label=1995, prediction=1992.8693143974576)
# Row(label=1995, prediction=1998.1018714522324)
# Row(label=1995, prediction=2000.030034117932)
# Row(label=1995, prediction=1990.9392097762568)
# Row(label=1995, prediction=1994.4922852883076)
# Row(label=1995, prediction=1993.1131500980218)
# Row(label=1995, prediction=1991.9041266862373)
# Row(label=1995, prediction=1997.4379234603296)
# Row(label=1995, prediction=1998.1060395593292)
# Row(label=1995, prediction=1992.349695083726)
# Row(label=1995, prediction=1996.6102719537503)
# Row(label=1995, prediction=1994.362525614605)
# Row(label=1995, prediction=2002.5364587427623)
# Row(label=1995, prediction=1992.0712228170996)
# Row(label=1995, prediction=1995.6497425881555)
# Row(label=1995, prediction=1991.9149941964163)
# Row(label=1995, prediction=1991.3906628106834)
# Row(label=1995, prediction=2001.2017442590816)
# Row(label=1995, prediction=1994.9876757147117)
# Row(label=1995, prediction=1995.4384012414314)
# Row(label=1995, prediction=1997.5816744539854)
# Row(label=1995, prediction=1994.110124894842)
# Row(label=1995, prediction=2000.9195123121585)
# Row(label=1995, prediction=2000.5954600045081)
# Row(label=1995, prediction=1997.1940462685398)
# Row(label=1995, prediction=1999.8027783124337)
# Row(label=1995, prediction=1998.058012935648)
# Row(label=1995, prediction=1998.1285529700647)
# Row(label=1995, prediction=1998.712091432544)
# Row(label=1995, prediction=2000.8999590096216)
# Row(label=1995, prediction=1999.4552433314825)
# Row(label=1995, prediction=1999.4322117485697)
# Row(label=1995, prediction=2000.328373448763)
# Row(label=1995, prediction=2000.6161398602376)
# Row(label=1995, prediction=2002.0504724744023)
# Row(label=1995, prediction=2000.9855446155716)
# Row(label=1995, prediction=1999.6564385597023)
# Row(label=1995, prediction=2002.2649767717016)
# Row(label=1996, prediction=1990.2714814744877)
# Row(label=1996, prediction=1990.664105500578)
# Row(label=1996, prediction=1990.0065442556604)
# Row(label=1996, prediction=1992.2504951577648)
# Row(label=1996, prediction=1996.3517317455053)
# Row(label=1996, prediction=1988.6316965848723)
# Row(label=1996, prediction=1991.5483564869694)
# Row(label=1996, prediction=1997.435913441069)
# Row(label=1996, prediction=1997.4630512143867)
# Row(label=1996, prediction=1993.767683253871)
# Row(label=1996, prediction=1997.9624982456812)
# Row(label=1996, prediction=1991.3367684008604)
# Row(label=1996, prediction=2001.0392115394443)
# Row(label=1996, prediction=1999.917240815092)
# Row(label=1996, prediction=1989.9994146725319)
# Row(label=1996, prediction=1995.9820207657774)
# Row(label=1996, prediction=1996.319338736021)
# Row(label=1996, prediction=1997.375101962537)
# Row(label=1996, prediction=2000.9130461649565)
# Row(label=1996, prediction=1994.9924354433815)
# Row(label=1996, prediction=1998.8744580519055)
# Row(label=1996, prediction=2001.993084676521)
# Row(label=1996, prediction=1998.6439422437509)
# Row(label=1996, prediction=1999.3708330419954)
# Row(label=1996, prediction=1994.8157580276304)
# Row(label=1996, prediction=1998.6803018474902)
# Row(label=1996, prediction=2000.2265102640426)
# Row(label=1996, prediction=1996.0407647557606)
# Row(label=1996, prediction=1994.3722781647623)
# Row(label=1996, prediction=2000.3889051742717)
# Row(label=1996, prediction=2001.9602156090734)
# Row(label=1996, prediction=1997.616025057298)
# Row(label=1996, prediction=1996.7661863680316)
# Row(label=1996, prediction=2001.4569560021346)
# Row(label=1996, prediction=1997.4176001695714)
# Row(label=1996, prediction=1998.2334258579885)
# Row(label=1996, prediction=1999.1625836548383)
# Row(label=1996, prediction=2000.0115389820016)
# Row(label=1996, prediction=1996.0274089125055)
# Row(label=1996, prediction=1997.9263987878885)
# Row(label=1996, prediction=1997.0194661653115)
# Row(label=1996, prediction=1999.2284738556577)
# Row(label=1996, prediction=1998.9305896266192)
# Row(label=1996, prediction=1999.2351730219445)
# Row(label=1996, prediction=1995.2043190118777)
# Row(label=1996, prediction=1995.29672798057)
# Row(label=1996, prediction=1998.2104215085656)
# Row(label=1996, prediction=2001.833279245599)
# Row(label=1996, prediction=1999.3879895264959)
# Row(label=1996, prediction=1998.236987487882)
# Row(label=1996, prediction=2000.185402430196)
# Row(label=1996, prediction=2002.3794690504133)
# Row(label=1996, prediction=1998.7401678398653)
# Row(label=1996, prediction=1998.8705878519627)
# Row(label=1996, prediction=1995.212837933053)
# Row(label=1996, prediction=2000.5373744091)
# Row(label=1996, prediction=2002.4527114031464)
# Row(label=1996, prediction=1999.7963341537838)
# Row(label=1996, prediction=2003.3832451455269)
# Row(label=1996, prediction=2002.3528149187005)
# Row(label=1997, prediction=1990.025531290624)
# Row(label=1997, prediction=1990.9666567202605)
# Row(label=1997, prediction=1991.4809908919747)
# Row(label=1997, prediction=1995.1549546170545)
# Row(label=1997, prediction=1991.6058141760936)
# Row(label=1997, prediction=1988.0368289745702)
# Row(label=1997, prediction=1993.4835079687755)
# Row(label=1997, prediction=1997.8279570064963)
# Row(label=1997, prediction=1994.349679206186)
# Row(label=1997, prediction=1992.4762071984987)
# Row(label=1997, prediction=2001.4179199651032)
# Row(label=1997, prediction=1993.715588566357)
# Row(label=1997, prediction=1990.9271424245328)
# Row(label=1997, prediction=2000.4464024636338)
# Row(label=1997, prediction=1996.2786916720545)
# Row(label=1997, prediction=2000.9941547992935)
# Row(label=1997, prediction=1995.5749834812043)
# Row(label=1997, prediction=1994.967614128844)
# Row(label=1997, prediction=2001.255876364956)
# Row(label=1997, prediction=2000.6374062497039)
# Row(label=1997, prediction=1998.8965217045616)
# Row(label=1997, prediction=1991.6112998520894)
# Row(label=1997, prediction=1999.6169047719293)
# Row(label=1997, prediction=1996.113244879479)
# Row(label=1997, prediction=1992.8461512255699)
# Row(label=1997, prediction=1998.097290459794)
# Row(label=1997, prediction=1989.2751977551452)
# Row(label=1997, prediction=1996.2176303190276)
# Row(label=1997, prediction=2003.7504726169598)
# Row(label=1997, prediction=1997.9102047700346)
# Row(label=1997, prediction=1988.6576072378064)
# Row(label=1997, prediction=1994.2963177992171)
# Row(label=1997, prediction=1998.9425306456635)
# Row(label=1997, prediction=1996.0257805881147)
# Row(label=1997, prediction=1998.4813265072232)
# Row(label=1997, prediction=2001.0807889851715)
# Row(label=1997, prediction=1999.4687818811824)
# Row(label=1997, prediction=2002.813063095126)
# Row(label=1997, prediction=1998.857623250918)
# Row(label=1997, prediction=2000.4424586994053)
# Row(label=1997, prediction=1997.4702134881936)
# Row(label=1997, prediction=1997.0228702423954)
# Row(label=1997, prediction=1999.0964006276604)
# Row(label=1997, prediction=1998.8694261618205)
# Row(label=1997, prediction=1998.5895031409646)
# Row(label=1997, prediction=1999.549818439728)
# Row(label=1997, prediction=1995.4052746421012)
# Row(label=1997, prediction=1998.8200867247908)
# Row(label=1997, prediction=2000.3650219982048)
# Row(label=1997, prediction=1994.8942983094862)
# Row(label=1997, prediction=2002.5871556345164)
# Row(label=1997, prediction=2001.9011930471684)
# Row(label=1997, prediction=2002.1862591098577)
# Row(label=1997, prediction=2001.3191132698896)
# Row(label=1997, prediction=1994.881832658426)
# Row(label=1997, prediction=1998.0645261138052)
# Row(label=1997, prediction=2000.6176517536292)
# Row(label=1997, prediction=2001.4109036042294)
# Row(label=1997, prediction=2002.8366664677797)
# Row(label=1997, prediction=2001.2439247532166)
# Row(label=1997, prediction=1997.1618650468804)
# Row(label=1997, prediction=2001.6572008171015)
# Row(label=1997, prediction=2002.303742544607)
# Row(label=1997, prediction=1998.8481766529528)
# Row(label=1997, prediction=2002.2544665333533)
# Row(label=1997, prediction=2005.8790676038939)
# Row(label=1997, prediction=2001.9279759055353)
# Row(label=1997, prediction=2003.6087611888909)
# Row(label=1997, prediction=2003.72394697248)
# Row(label=1997, prediction=2002.760588447609)
# Row(label=1997, prediction=2002.970184677259)
# Row(label=1998, prediction=1994.0185074946344)
# Row(label=1998, prediction=1992.2198001615302)
# Row(label=1998, prediction=1989.5606317507018)
# Row(label=1998, prediction=1991.3162030066528)
# Row(label=1998, prediction=1998.5414604822186)
# Row(label=1998, prediction=1993.9159426456893)
# Row(label=1998, prediction=1990.451563020208)
# Row(label=1998, prediction=1999.4920321349962)
# Row(label=1998, prediction=1992.0990821329758)
# Row(label=1998, prediction=1997.3199498712759)
# Row(label=1998, prediction=1996.6394590576847)
# Row(label=1998, prediction=1993.8398052133477)
# Row(label=1998, prediction=1994.2904714245255)
# Row(label=1998, prediction=1993.9494126625007)
# Row(label=1998, prediction=1994.3016166763998)
# Row(label=1998, prediction=1995.328424605132)
# Row(label=1998, prediction=1997.8118769854902)
# Row(label=1998, prediction=1997.0745732787182)
# Row(label=1998, prediction=1991.3757239572956)
# Row(label=1998, prediction=1993.3578916799454)
# Row(label=1998, prediction=1999.878070763833)
# Row(label=1998, prediction=2004.7350149391775)
# Row(label=1998, prediction=1999.0727652520188)
# Row(label=1998, prediction=1993.9476520983192)
# Row(label=1998, prediction=1995.1890746927204)
# Row(label=1998, prediction=1994.8880465373277)
# Row(label=1998, prediction=2000.985038433547)
# Row(label=1998, prediction=1999.350392303177)
# Row(label=1998, prediction=2001.7195233941197)
# Row(label=1998, prediction=1996.6597985823933)
# Row(label=1998, prediction=1991.5317034426953)
# Row(label=1998, prediction=2001.351320209808)
# Row(label=1998, prediction=1998.8092856585045)
# Row(label=1998, prediction=1997.0288490506994)
# Row(label=1998, prediction=2001.180740663758)
# Row(label=1998, prediction=1997.364353032649)
# Row(label=1998, prediction=1995.9600031542539)
# Row(label=1998, prediction=1994.4607777437589)
# Row(label=1998, prediction=1998.9907042826549)
# Row(label=1998, prediction=1994.1616948813592)
# Row(label=1998, prediction=2001.3031170811357)
# Row(label=1998, prediction=1998.3947406329885)
# Row(label=1998, prediction=2000.8189872046792)
# Row(label=1998, prediction=1998.7056358296923)
# Row(label=1998, prediction=1997.3750417935198)
# Row(label=1998, prediction=1997.1697483689313)
# Row(label=1998, prediction=1999.5969537787012)
# Row(label=1998, prediction=1998.483604198202)
# Row(label=1998, prediction=1999.4274019713966)
# Row(label=1998, prediction=1998.7562822765233)
# Row(label=1998, prediction=2001.7036729043305)
# Row(label=1998, prediction=1998.0756456413803)
# Row(label=1998, prediction=2001.6507826544052)
# Row(label=1998, prediction=2004.1851100399635)
# Row(label=1998, prediction=2002.2648310819916)
# Row(label=1998, prediction=2000.3065515244332)
# Row(label=1998, prediction=1997.7591942402325)
# Row(label=1998, prediction=2001.3429507785077)
# Row(label=1998, prediction=1996.8942611268474)
# Row(label=1998, prediction=1996.7542138912365)
# Row(label=1998, prediction=2005.3513853790525)
# Row(label=1998, prediction=1995.4138105495247)
# Row(label=1998, prediction=1997.1857491882536)
# Row(label=1998, prediction=2000.1860373704787)
# Row(label=1998, prediction=2000.290839198244)
# Row(label=1998, prediction=2001.5242973407574)
# Row(label=1998, prediction=1999.5940834070177)
# Row(label=1998, prediction=1999.8683734318747)
# Row(label=1998, prediction=2000.6833402989962)
# Row(label=1998, prediction=1993.745917674486)
# Row(label=1998, prediction=1999.284994827636)
# Row(label=1998, prediction=2002.365700468726)
# Row(label=1998, prediction=2000.048524925209)
# Row(label=1998, prediction=2001.8955025418402)
# Row(label=1998, prediction=2004.8046434239957)
# Row(label=1998, prediction=2002.3592960824835)
# Row(label=1999, prediction=2002.5387168922964)
# Row(label=1999, prediction=1993.8446828806284)
# Row(label=1999, prediction=1991.4820902667363)
# Row(label=1999, prediction=1993.4506190040618)
# Row(label=1999, prediction=1993.6968650946658)
# Row(label=1999, prediction=1994.930558751085)
# Row(label=1999, prediction=1994.9526772608715)
# Row(label=1999, prediction=2001.8475318258736)
# Row(label=1999, prediction=1994.3823487050483)
# Row(label=1999, prediction=2001.302850072026)
# Row(label=1999, prediction=1990.4901716231145)
# Row(label=1999, prediction=1994.9641820186787)
# Row(label=1999, prediction=1988.7096224714435)
# Row(label=1999, prediction=1990.5651157987834)
# Row(label=1999, prediction=1982.7313522590136)
# Row(label=1999, prediction=1994.7295795695027)
# Row(label=1999, prediction=1996.3752704020242)
# Row(label=1999, prediction=1999.3459999785075)
# Row(label=1999, prediction=1999.5554434413727)
# Row(label=1999, prediction=1997.8811002674283)
# Row(label=1999, prediction=1995.8834523195553)
# Row(label=1999, prediction=1994.8594094533116)
# Row(label=1999, prediction=2004.2555595927802)
# Row(label=1999, prediction=1991.117028936697)
# Row(label=1999, prediction=1996.9136387906162)
# Row(label=1999, prediction=1992.002989231324)
# Row(label=1999, prediction=1992.0839824247305)
# Row(label=1999, prediction=1997.5082154976726)
# Row(label=1999, prediction=1996.550380022789)
# Row(label=1999, prediction=1992.6165568102174)
# Row(label=1999, prediction=1998.6791175012402)
# Row(label=1999, prediction=1996.8249814368662)
# Row(label=1999, prediction=1994.265185415327)
# Row(label=1999, prediction=2001.4201026718447)
# Row(label=1999, prediction=1999.9653557787885)
# Row(label=1999, prediction=2000.1399933195762)
# Row(label=1999, prediction=1995.3030916693099)
# Row(label=1999, prediction=1998.2936060149702)
# Row(label=1999, prediction=2003.3581545525378)
# Row(label=1999, prediction=1997.6727012599263)
# Row(label=1999, prediction=1998.1065227290874)
# Row(label=1999, prediction=2002.4704502807758)
# Row(label=1999, prediction=2000.0692147554641)
# Row(label=1999, prediction=1996.0864692289526)
# Row(label=1999, prediction=1995.620635691815)
# Row(label=1999, prediction=2002.9405430594718)
# Row(label=1999, prediction=2003.6025412533725)
# Row(label=1999, prediction=2003.689914852404)
# Row(label=1999, prediction=1998.1707862969351)
# Row(label=1999, prediction=1998.0454326841104)
# Row(label=1999, prediction=1987.9905371018017)
# Row(label=1999, prediction=2007.628232558784)
# Row(label=1999, prediction=2000.091979772171)
# Row(label=1999, prediction=1995.9599581951734)
# Row(label=1999, prediction=1997.0003750903552)
# Row(label=1999, prediction=2004.07441148463)
# Row(label=1999, prediction=2001.4362300606235)
# Row(label=1999, prediction=2001.7376543949201)
# Row(label=1999, prediction=1997.8656039122063)
# Row(label=1999, prediction=1995.3330610274163)
# Row(label=1999, prediction=2002.5976082699688)
# Row(label=1999, prediction=2001.090683796719)
# Row(label=1999, prediction=1995.888868267061)
# Row(label=1999, prediction=1995.6787990150826)
# Row(label=1999, prediction=1997.980705091891)
# Row(label=1999, prediction=2000.0228218737773)
# Row(label=1999, prediction=1996.2307168937143)
# Row(label=1999, prediction=2000.198032637254)
# ...
# Row(label=2008, prediction=2007.3330020526957)
# Row(label=2008, prediction=2002.268105220368)
# Row(label=2008, prediction=2003.2690810376162)
# Row(label=2008, prediction=1995.5953296748005)
# Row(label=2008, prediction=2001.1106552501767)
# Row(label=2008, prediction=2002.3854222357975)
# Row(label=2008, prediction=1997.864868457374)
# Row(label=2008, prediction=1996.7292039198144)
# Row(label=2008, prediction=2002.3003089441202)
# Row(label=2008, prediction=1997.3892989671372)
# Row(label=2008, prediction=2001.039798779585)
# Row(label=2008, prediction=2000.5032927951738)
# Row(label=2008, prediction=2001.5267698760133)
# Row(label=2008, prediction=2000.4957971025044)
# Row(label=2008, prediction=1999.006261863247)
# Row(label=2008, prediction=2001.9475746746666)
# Row(label=2008, prediction=2003.3983311901252)
# Row(label=2008, prediction=2000.5900375720921)
# Row(label=2008, prediction=2007.7788010762442)
# Row(label=2008, prediction=1998.9717254697139)
# Row(label=2008, prediction=2003.1973582505746)
# Row(label=2008, prediction=1995.8250979253894)
# Row(label=2008, prediction=2001.3132734783844)
# Row(label=2008, prediction=2001.08150717568)
# Row(label=2008, prediction=1999.3428359967174)
# Row(label=2008, prediction=1998.892113232024)
# Row(label=2008, prediction=2000.663779049726)
# Row(label=2008, prediction=1999.3390869221619)
# Row(label=2008, prediction=2000.1285454292963)
# Row(label=2008, prediction=2001.133449721379)
# Row(label=2008, prediction=1999.9540409806252)
# Row(label=2008, prediction=1997.0287634372867)
# Row(label=2008, prediction=2000.1616842181634)
# Row(label=2008, prediction=2001.6564742911958)
# Row(label=2008, prediction=2002.3795729630594)
# Row(label=2008, prediction=2001.4420250049488)
# Row(label=2008, prediction=2001.8044868364611)
# Row(label=2008, prediction=2001.184422439852)
# Row(label=2008, prediction=1998.168891837944)
# Row(label=2008, prediction=2001.9073435981777)
# Row(label=2008, prediction=2001.004171478352)
# Row(label=2008, prediction=2000.007711867714)
# Row(label=2008, prediction=2000.6228784977377)
# Row(label=2008, prediction=2003.7390764494567)
# Row(label=2008, prediction=1998.307082185091)
# Row(label=2008, prediction=1997.8690091887568)
# Row(label=2008, prediction=2001.3146817342188)
# Row(label=2008, prediction=2000.441561094913)
# Row(label=2008, prediction=1997.9140350105608)
# Row(label=2008, prediction=2000.4571879689452)
# Row(label=2008, prediction=2000.0753846821453)
# Row(label=2008, prediction=1999.9268534085832)
# Row(label=2008, prediction=1997.6394686836406)
# Row(label=2008, prediction=1999.6305492806532)
# Row(label=2008, prediction=1995.729133058244)
# Row(label=2008, prediction=1998.3769120308036)
# Row(label=2008, prediction=1999.4992719122674)
# Row(label=2008, prediction=2001.1356525913488)
# Row(label=2008, prediction=1999.785508722957)
# Row(label=2008, prediction=2001.2817238254581)
# Row(label=2008, prediction=2002.984309108896)
# Row(label=2008, prediction=2000.9814927678176)
# Row(label=2008, prediction=2000.9299652291186)
# Row(label=2008, prediction=2002.082428619046)
# Row(label=2008, prediction=2002.3169054841874)
# Row(label=2008, prediction=2006.409599677051)
# Row(label=2008, prediction=2001.0576816555365)
# Row(label=2008, prediction=2005.074423868142)
# Row(label=2008, prediction=2009.4696251847956)
# Row(label=2008, prediction=2000.5242988887944)
# Row(label=2008, prediction=2000.1437855722484)
# Row(label=2008, prediction=1999.411370653645)
# Row(label=2008, prediction=2000.7827174483953)
# Row(label=2008, prediction=2001.4374386774489)
# Row(label=2008, prediction=1999.2703957610752)
# Row(label=2008, prediction=2003.4019433109736)
# Row(label=2008, prediction=1999.447529447672)
# Row(label=2008, prediction=2001.1049493861071)
# Row(label=2008, prediction=2000.4094415180402)
# Row(label=2008, prediction=1998.6707911599462)
# Row(label=2008, prediction=2000.958351023923)
# Row(label=2008, prediction=2002.0455864543817)
# Row(label=2008, prediction=2003.699100095316)
# Row(label=2008, prediction=2002.403944516545)
# Row(label=2008, prediction=2000.35461143204)
# Row(label=2008, prediction=1997.8111699391122)
# Row(label=2008, prediction=2001.6779955454488)
# Row(label=2008, prediction=2001.2030573783002)
# Row(label=2008, prediction=2001.3660808152135)
# Row(label=2008, prediction=2002.1906652373327)
# Row(label=2008, prediction=2001.4049566326476)
# Row(label=2008, prediction=2005.2910879244862)
# Row(label=2008, prediction=2002.9834619083363)
# Row(label=2008, prediction=2001.6575196038566)
# Row(label=2008, prediction=2000.9786656594727)
# Row(label=2008, prediction=2002.7195222369185)
# Row(label=2008, prediction=2000.2945985618442)
# Row(label=2008, prediction=2004.969835484055)
# Row(label=2008, prediction=2000.4859679934918)
# Row(label=2008, prediction=1999.5028890958472)
# Row(label=2008, prediction=2002.270977000209)
# Row(label=2008, prediction=2003.245537672141)
# Row(label=2008, prediction=2001.1404222661133)
# Row(label=2008, prediction=2001.083360015109)
# Row(label=2008, prediction=2007.275278124198)
# Row(label=2008, prediction=2004.9547069227756)
# Row(label=2008, prediction=2004.7681214043537)
# Row(label=2008, prediction=2000.629368053568)
# Row(label=2008, prediction=1999.1139024046165)
# Row(label=2008, prediction=2006.082124495983)
# Row(label=2008, prediction=1999.200777963864)
# Row(label=2008, prediction=2002.5769838844437)
# Row(label=2008, prediction=2004.7053912837973)
# Row(label=2008, prediction=2003.4037550729724)
# Row(label=2008, prediction=2001.4467857097823)
# Row(label=2008, prediction=2001.222523082928)
# Row(label=2008, prediction=2003.51645423811)
# Row(label=2008, prediction=2000.2709183659445)
# Row(label=2008, prediction=2002.093451603445)
# Row(label=2008, prediction=1997.705559546764)
# Row(label=2008, prediction=2007.3476091777727)
# Row(label=2009, prediction=1995.486644745736)
# Row(label=2009, prediction=1996.9076977245156)
# Row(label=2009, prediction=1998.1916974407911)
# Row(label=2009, prediction=1994.308212321366)
# Row(label=2009, prediction=1995.2078657083227)
# Row(label=2009, prediction=1994.2692571350553)
# Row(label=2009, prediction=1991.240376621787)
# Row(label=2009, prediction=1995.1769780095544)
# Row(label=2009, prediction=1999.6536006226095)
# Row(label=2009, prediction=1993.9430265846315)
# Row(label=2009, prediction=1998.1288486266683)
# Row(label=2009, prediction=1999.158766976066)
# Row(label=2009, prediction=1995.7680458023033)
# Row(label=2009, prediction=1994.4126865435505)
# Row(label=2009, prediction=1998.036637020354)
# Row(label=2009, prediction=1996.7444527731375)
# Row(label=2009, prediction=2006.6740529928861)
# Row(label=2009, prediction=2003.508535380357)
# Row(label=2009, prediction=1994.2505166428825)
# Row(label=2009, prediction=1998.1416157535286)
# Row(label=2009, prediction=1994.716947588201)
# Row(label=2009, prediction=1996.8268907919633)
# Row(label=2009, prediction=2000.0411453104593)
# Row(label=2009, prediction=2000.730621986929)
# Row(label=2009, prediction=2001.4184838428946)
# Row(label=2009, prediction=1995.3279876470726)
# Row(label=2009, prediction=2002.437130187309)
# Row(label=2009, prediction=1997.1141104171363)
# Row(label=2009, prediction=1989.86000618035)
# Row(label=2009, prediction=1984.1053787911353)
# Row(label=2009, prediction=1990.0669876440709)
# Row(label=2009, prediction=1998.8964202550974)
# Row(label=2009, prediction=2008.628888127752)
# Row(label=2009, prediction=2000.280825176949)
# Row(label=2009, prediction=1996.4476893368278)
# Row(label=2009, prediction=2003.572894376612)
# Row(label=2009, prediction=1991.635404598108)
# Row(label=2009, prediction=1998.898054437911)
# Row(label=2009, prediction=1995.523877644827)
# Row(label=2009, prediction=1998.9012248427439)
# Row(label=2009, prediction=1998.4647561208915)
# Row(label=2009, prediction=1998.423823093678)
# Row(label=2009, prediction=1992.4162418685637)
# Row(label=2009, prediction=1999.5332433654053)
# Row(label=2009, prediction=1997.6654030592458)
# Row(label=2009, prediction=1998.7005619165488)
# Row(label=2009, prediction=1991.795473049822)
# Row(label=2009, prediction=2001.3971074592685)
# Row(label=2009, prediction=2003.842083471425)
# Row(label=2009, prediction=2002.2568504467406)
# Row(label=2009, prediction=1998.9931642564084)
# Row(label=2009, prediction=1996.5463606306848)
# Row(label=2009, prediction=2001.2409085919119)
# Row(label=2009, prediction=2000.911282118089)
# Row(label=2009, prediction=1992.7013771026918)
# Row(label=2009, prediction=1999.5910552602688)
# Row(label=2009, prediction=2001.509352845803)
# Row(label=2009, prediction=2000.4131612822289)
# Row(label=2009, prediction=1996.9539548621324)
# Row(label=2009, prediction=1996.4070724354715)
# Row(label=2009, prediction=2000.2083372311845)
# Row(label=2009, prediction=1995.4641236499544)
# Row(label=2009, prediction=2002.0281708968896)
# Row(label=2009, prediction=1995.5116333290175)
# Row(label=2009, prediction=1999.0122963675767)
# Row(label=2009, prediction=1992.4339926587393)
# Row(label=2009, prediction=2008.3818355973624)
# Row(label=2009, prediction=1998.7646622397522)
# Row(label=2009, prediction=2001.576014518127)
# Row(label=2009, prediction=2002.316130677651)
# Row(label=2009, prediction=2005.021777196521)
# Row(label=2009, prediction=2002.4367146582658)
# Row(label=2009, prediction=2001.1143395895501)
# Row(label=2009, prediction=2002.7086372883398)
# Row(label=2009, prediction=2000.084466924214)
# Row(label=2009, prediction=2000.9410813248153)
# Row(label=2009, prediction=2000.034158072226)
# Row(label=2009, prediction=2000.9449565111292)
# Row(label=2009, prediction=1998.523695168174)
# Row(label=2009, prediction=1998.4995348112502)
# Row(label=2009, prediction=2002.7792083673896)
# Row(label=2009, prediction=2002.337878119786)
# Row(label=2009, prediction=2007.757649396894)
# Row(label=2009, prediction=2000.5380920598461)
# Row(label=2009, prediction=2001.5550869350432)
# Row(label=2009, prediction=1998.234040664755)
# Row(label=2009, prediction=2005.148838802622)
# Row(label=2009, prediction=2003.3453641378674)
# Row(label=2009, prediction=1999.6586008105312)
# Row(label=2009, prediction=2000.177075269092)
# Row(label=2009, prediction=2003.263004840168)
# Row(label=2009, prediction=1999.33793927402)
# Row(label=2009, prediction=1997.2848964186956)
# Row(label=2009, prediction=1998.7332151067715)
# Row(label=2009, prediction=2004.4516851538954)
# Row(label=2009, prediction=2002.442749726954)
# Row(label=2009, prediction=2002.1823820586712)
# Row(label=2009, prediction=2002.525887517708)
# Row(label=2009, prediction=2001.0931265513868)
# Row(label=2009, prediction=2001.2506280374535)
# Row(label=2009, prediction=1996.5861705618095)
# Row(label=2009, prediction=2000.006372823172)
# Row(label=2009, prediction=2000.070005878306)
# Row(label=2009, prediction=2004.0969568506114)
# Row(label=2009, prediction=1999.8414206778493)
# Row(label=2009, prediction=2002.2027076918678)
# Row(label=2009, prediction=2004.2687814893407)
# Row(label=2009, prediction=2002.3959364785883)
# Row(label=2009, prediction=2001.0915576550578)
# Row(label=2009, prediction=2001.4582121004557)
# Row(label=2009, prediction=2002.8306883814055)
# Row(label=2009, prediction=2001.5122625034512)
# Row(label=2009, prediction=1996.6363410308322)
# Row(label=2009, prediction=1998.9004610717002)
# Row(label=2009, prediction=2003.7977204996557)
# Row(label=2009, prediction=1996.9441919931976)
# Row(label=2009, prediction=2001.353526787674)
# Row(label=2009, prediction=2001.1114526116692)
# Row(label=2009, prediction=2001.5784531924114)
# Row(label=2009, prediction=2000.8841527264785)
# Row(label=2009, prediction=2000.7460849053775)
# Row(label=2009, prediction=1997.4291418026712)
# Row(label=2009, prediction=2004.08297888073)
# Row(label=2009, prediction=2000.442320104378)
# Row(label=2009, prediction=1998.1236617532238)
# Row(label=2009, prediction=2003.4590027833763)
# Row(label=2009, prediction=2002.5539928728442)
# Row(label=2009, prediction=2001.2602798448174)
# Row(label=2009, prediction=2000.4896971945382)
# Row(label=2009, prediction=2001.8240843880362)
# Row(label=2009, prediction=2004.0057098319717)
# Row(label=2009, prediction=2005.415581602609)
# Row(label=2009, prediction=2002.9811256669893)
# Row(label=2009, prediction=2001.3152587869326)
# Row(label=2009, prediction=2004.5674367999736)
# Row(label=2009, prediction=2002.2131673688543)
# Row(label=2009, prediction=2003.0896316007402)
# Row(label=2009, prediction=2002.6645285901818)
# Row(label=2009, prediction=2003.2561868224536)
# Row(label=2009, prediction=2004.2286537967314)
# Row(label=2009, prediction=2004.6003224811539)
# Row(label=2009, prediction=2000.857814851164)
# Row(label=2009, prediction=1997.9816585897713)
# Row(label=2009, prediction=2003.0588144035466)
# Row(label=2009, prediction=2003.0333448762365)
# Row(label=2009, prediction=2001.5724813851853)
# Row(label=2009, prediction=2001.36424851225)
# Row(label=2009, prediction=2001.004935687521)
# Row(label=2009, prediction=2001.633120782701)
# Row(label=2009, prediction=2004.3957673677585)
# Row(label=2009, prediction=2000.9421126046095)
# Row(label=2009, prediction=2001.0880284336351)
# Row(label=2009, prediction=2000.7545791072982)
# Row(label=2009, prediction=2001.3451514669907)
# Row(label=2009, prediction=2000.1788727043047)
# Row(label=2009, prediction=2002.5939000763374)
# Row(label=2009, prediction=2003.1927466936002)
# Row(label=2009, prediction=1997.8540691608964)
# Row(label=2009, prediction=2002.3892335327873)
# Row(label=2009, prediction=2009.1657548617834)
# Row(label=2009, prediction=2002.8508752801397)
# Row(label=2009, prediction=2004.185612281731)
# Row(label=2009, prediction=2004.1743519411636)
# Row(label=2009, prediction=2001.687928115452)
# Row(label=2009, prediction=2002.6360144930393)
# Row(label=2009, prediction=2003.7625415196399)
# Row(label=2009, prediction=2002.499435720671)
# Row(label=2009, prediction=1999.965737127396)
# Row(label=2009, prediction=2002.1335145007126)
# Row(label=2009, prediction=2000.885441083381)
# Row(label=2009, prediction=2005.2426041696895)
# Row(label=2009, prediction=2001.2605679080896)
# Row(label=2009, prediction=2006.3926892612926)
# Row(label=2009, prediction=2003.7849730948153)
# Row(label=2010, prediction=1996.7655946625111)
# Row(label=2010, prediction=1997.7902801530063)
# Row(label=2010, prediction=1998.4083027218262)
# Row(label=2010, prediction=1993.6887676476454)
# Row(label=2010, prediction=1995.8027111291362)
# Row(label=2010, prediction=1997.0792741573555)
# Row(label=2010, prediction=1993.881687914152)
# Row(label=2010, prediction=1998.9326046096473)
# Row(label=2010, prediction=2001.9238152741652)
# Row(label=2010, prediction=2001.1851584503984)
# Row(label=2010, prediction=2005.3560849109842)
# Row(label=2010, prediction=1998.527217847867)
# Row(label=2010, prediction=1995.1745235444696)
# Row(label=2010, prediction=2003.1286810398776)
# Row(label=2010, prediction=2003.7447319083205)
# Row(label=2010, prediction=2001.056369212492)
# Row(label=2010, prediction=2000.7095396765997)
# Row(label=2010, prediction=2000.6830709294)
# Row(label=2010, prediction=2004.0026506811564)
# Row(label=2010, prediction=2001.172516544691)
# Row(label=2010, prediction=2001.565122483956)
# Row(label=2010, prediction=1997.3271803856119)
# Row(label=2010, prediction=2001.2934256864442)
# Row(label=2010, prediction=2001.4958089326826)
# Row(label=2010, prediction=2008.7612370809402)
# Row(label=2010, prediction=2000.7543038085846)
# Row(label=2010, prediction=2006.4075800519688)
# Row(label=2010, prediction=1998.8491552333041)
# Row(label=2010, prediction=1999.8421126639605)
# Row(label=2010, prediction=2000.6601915789252)
# Row(label=2010, prediction=2001.3496290405808)
# Row(label=2010, prediction=2002.5508496582806)
# Row(label=2010, prediction=2000.1556088949906)
# Row(label=2010, prediction=2002.4110952336607)
# Row(label=2010, prediction=1997.5389570418497)
# Row(label=2010, prediction=2003.0383379719294)
# Row(label=2010, prediction=1998.7959069596534)
# Row(label=2010, prediction=2006.1143357253268)
# Row(label=2010, prediction=1997.7508109386163)
# Row(label=2010, prediction=1999.5669527494138)
# Row(label=2010, prediction=2002.8306579866767)
# Row(label=2010, prediction=1999.9365475861289)
# Row(label=2010, prediction=2001.0524065119505)
# Row(label=2010, prediction=2003.5297020456583)
# Row(label=2010, prediction=2005.272250475108)
# Row(label=2010, prediction=2003.8601840961317)
# Row(label=2010, prediction=2004.587012736607)

# %% [markdown]
# Examiner les métriques

# %%
evaluator.setMetricName('r2').evaluate(pred_test)
# Out:
# 0.1564198653389689

# %%
evaluator.setMetricName('rmse').evaluate(pred_test)
# Out:
# 10.206660175163833

# %% [markdown]
# RMSE measures the differences between predicted values by the model and the actual values. However, RMSE alone is meaningless until we compare with the actual “MV” value, such as mean, min and max

# %%
train.describe().show()
# Out:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             41247|
# |   mean|1998.3525832181735|
# | stddev|10.986808864337556|
# |    min|              1922|
# |    max|              2010|
# +-------+------------------+

# %%
test.describe().show()
# Out:
# +-------+------------------+
# |summary|             label|
# +-------+------------------+
# |  count|             10311|
# |   mean|1998.3273203375036|
# | stddev|11.113261770668421|
# |    min|              1926|
# |    max|              2010|
# +-------+------------------+

# %% [markdown]
# View the optimal model information

# %%
bestModel = cv_model.bestModel.coefficients

# %%
bestModel
# Out:
# DenseVector([0.7608, -0.0558, -0.0747, 0.1319, 0.0133, -0.2082, -0.0612, -0.0458, -0.1376, 0.0989, -0.4352, 0.0504])

# %%
spark.stop()
